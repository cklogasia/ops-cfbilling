# %%
import papermill as pm

# Define the paths to your notebooks
notebook_paths = [
    r"C:\Users\erictr\CF Outbound Billing Method.ipynb",
    r"C:\Users\erictr\CF Inbound Billing Method.ipynb", 
    r"C:\Users\erictr\Provision Report.ipynb"
]

# Execute notebooks in sequence
for notebook_path in notebook_paths:
    print(f"🚀 Executing: {notebook_path}")
    pm.execute_notebook(
        notebook_path,
        notebook_path,  # Output to same file
        parameters={}
    )
    print(f"✅ Completed: {notebook_path}")

print("🎉 All notebooks executed successfully!")
